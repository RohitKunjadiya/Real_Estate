# %%
import re

import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv('apartment.csv')

df.shape
# Out:
# (620, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 620 entries, 0 to 619
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SocietyName     383 non-null    object
#  1   BHK             620 non-null    object
#  2   Furnishing      620 non-null    object
#  3   BuiltUpArea     620 non-null    object
#  4   Locality        620 non-null    object
#  5   NearbyPlace_1   619 non-null    object
#  6   DistanceAway_1  619 non-null    object
#  7   NearbyPlace_2   619 non-null    object
#  8   DistanceAway_2  619 non-null    object
#  9   Description     620 non-null    object
#  10  Highlights      137 non-null    object
# dtypes: object(11)
# memory usage: 53.4+ KB

# %%
df.duplicated().sum()
# Out:
# 55

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (565, 11)

# %%
df.isna().sum()
# Out:
# SocietyName       214
# BHK                 0
# Furnishing          0
# BuiltUpArea         0
# Locality            0
# NearbyPlace_1       1
# DistanceAway_1      1
# NearbyPlace_2       1
# DistanceAway_2      1
# Description         0
# Highlights        437
# dtype: int64

# %%
df = df[~(df['SocietyName'].isna())]

df.reset_index(drop=True, inplace=True)

# %%
df.shape
# Out:
# (351, 11)

# %%
df.drop_duplicates(subset=['SocietyName'], inplace=True)

# %%
df.shape

df.reset_index(drop=True, inplace=True)

# %%
df.isna().sum()
# Out:
# SocietyName         0
# BHK                 0
# Furnishing          0
# BuiltUpArea         0
# Locality            0
# NearbyPlace_1       0
# DistanceAway_1      0
# NearbyPlace_2       0
# DistanceAway_2      0
# Description         0
# Highlights        132
# dtype: int64

# %%
df.sample(10)
# Out:
#                         SocietyName                                       BHK  \
# 179                Mahaveer Heights     3 BHK Flat for rent in Bhimrad, Surat
# 72     Rajhans Builder Surat Campus       2 BHK Flat for rent in Limla, Surat
# 163             Sai Jyoti Residency  2 BHK Flat for rent in Udhna Zone, Surat
# 169              JT Stuti Residency  2 BHK Flat for rent in Adajan Gam, Surat
# 159              Shrungal Solitaire  2 BHK Flat for rent in Udhna Zone, Surat
# 9    Happy Home Nakshatra Solitaire    3 BHK Flat for rent in Palanpur, Surat
# 50        Raj Green Raj Green Hills         5 BHK Flat for rent in Pal, Surat
# 35        Monarch Monarch Residency    3 BHK Flat for rent in Palanpur, Surat
# 76     Happy Home Nakshatra Heights     3 BHK Flat for rent in Pal Gam, Surat
# 107              Happy Home Nandini        3 BHK Flat for rent in Vesu, Surat
#
#           Furnishing BuiltUpArea                                  Locality  \
# 179  Fully Furnished  2200 sq.ft     3 BHK Flat for rent in Bhimrad, Surat
# 72   Fully Furnished  1300 sq.ft       2 BHK Flat for rent in Limla, Surat
# 163      Unfurnished  1200 sq.ft  2 BHK Flat for rent in Udhna Zone, Surat
# 169  Fully Furnished  1175 sq.ft  2 BHK Flat for rent in Adajan Gam, Surat
# 159      Unfurnished  1120 sq.ft  2 BHK Flat for rent in Udhna Zone, Surat
# 9     Semi Furnished  1518 sq.ft    3 BHK Flat for rent in Palanpur, Surat
# 50   Fully Furnished  7500 sq.ft         5 BHK Flat for rent in Pal, Surat
# 35    Semi Furnished  2000 sq.ft    3 BHK Flat for rent in Palanpur, Surat
# 76   Fully Furnished  1458 sq.ft     3 BHK Flat for rent in Pal Gam, Surat
# 107      Unfurnished  1750 sq.ft        3 BHK Flat for rent in Vesu, Surat
#
#                                          NearbyPlace_1  DistanceAway_1  \
# 179               Bhagwan Mahavir International School  is 0.1 km away
# 72              Sharda Vidhyalay School ( Ichchapore )  is 6.9 km away
# 163                           Navaprajna Public School  is 3.9 km away
# 169                            Sardar Patel Vidhyalaya  is 0.7 km away
# 159                   Galaxy Army International School  is 0.1 km away
# 9                                    L P Savani School  is 0.7 km away
# 50                             Sardar Patel Vidhyalaya  is 0.1 km away
# 35   Shree Jalaram International School ( SJIS Scho...  is 0.2 km away
# 76                    L.P. Savani International School  is 0.8 km away
# 107                                Agarwal Vidya Vihar  is 0.8 km away
#
#                                          NearbyPlace_2  DistanceAway_2  \
# 179           Shraddha Clinic - Dr. Khushbu Patel Jani  is 1.1 km away
# 72      SOCH- Institute Of Mental Health & Deaddiction  is 9.2 km away
# 163            Kauvery Hospital Marathahalli Bengaluru  is 1.1 km away
# 169                                   Ami Eye Hospital  is 0.6 km away
# 159                                  Aarogyam Hospital  is 0.1 km away
# 9       Marigold hospital,ICU & Cardio-Diabetes center  is 0.6 km away
# 50                                Drashti Eye Hospital  is 0.8 km away
# 35                              Dhwani Hospital & ICCU  is 0.3 km away
# 76   Dr Nirav Soni | Joint Replacement Surgeon| Art...  is 0.2 km away
# 107                   Amritam Multispeciality Hospital  is 1.1 km away
#
#                                            Description  \
# 179  This Apartment can be a comfortable and afford...
# 72   Are you looking for an affordable Apartment fo...
# 163  This Apartment can be a comfortable and afford...
# 169  Check this beautiful 2 BHK Apartment available...
# 159  This Apartment can be a comfortable and afford...
# 9    The project has 3 bhk multistorey apartments. ...
# 50   This Apartment can be a comfortable and afford...
# 35   This Apartment can be a comfortable and afford...
# 76   Check this beautiful 3 BHK Apartment available...
# 107  If you are looking for a modern house on rent ...
#
#                                             Highlights
# 179                                                NaN
# 72   Special Highlights24x7 SecurityLiftPower Backu...
# 163                                                NaN
# 169                                                NaN
# 159                                                NaN
# 9    Special Highlights24x7 SecurityCycling & Joggi...
# 50   Special Highlights24x7 SecurityChildren Play A...
# 35                                                 NaN
# 76   Special Highlights24x7 SecurityChildren Play A...
# 107                                                NaN

# %%
df.drop(columns=['Highlights','Locality'], inplace=True)

# %%
df.isna().sum()
# Out:
# SocietyName       0
# BHK               0
# Furnishing        0
# BuiltUpArea       0
# NearbyPlace_1     0
# DistanceAway_1    0
# NearbyPlace_2     0
# DistanceAway_2    0
# Description       0
# dtype: int64

# %%
df.sample(1)
# Out:
#                SocietyName                                    BHK  \
# 119  Rameshwaram Devbhoomi  4 BHK Flat for rent in Bhimrad, Surat
#
#           Furnishing BuiltUpArea  \
# 119  Fully Furnished  3500 sq.ft
#
#                                          NearbyPlace_1  DistanceAway_1  \
# 119  Bhagwan Mahavir Concept School | BMCS | Cambri...  is 0.1 km away
#
#                   NearbyPlace_2 DistanceAway_2  \
# 119  Ayushyam children hospital   is 1 km away
#
#                                            Description
# 119  This is a modern and stylish home available fo...

# %% [markdown]
# # Recommendation using Nearby Location

# %%
df['Bhk'] = df['BHK'].str.split(" ").str.get(0)
df['Description'] = df['Description'].str.split('.').apply(lambda x: '.'.join(x[:-4]) if len(x) > 4 else '')

df.drop('BHK', axis=1, inplace=True)

# %%
df.head(1)
# Out:
#    SocietyName      Furnishing BuiltUpArea      NearbyPlace_1  DistanceAway_1  \
# 0  Aston Homes  Semi Furnished  2200 sq.ft  L P Savani School  is 0.2 km away
#
#                NearbyPlace_2  DistanceAway_2  \
# 0  BACHPAN Children hospital  is 0.4 km away
#
#                                          Description Bhk
# 0  Your search for a spacious home at affordable ...   3

# %%
df['NearbyPlaces'] = df.apply(lambda row: {
    row['NearbyPlace_1']: row['DistanceAway_1'],
    row['NearbyPlace_2']: row['DistanceAway_2']
}, axis=1)

df.drop(columns=['NearbyPlace_1', 'DistanceAway_1', 'NearbyPlace_2', 'DistanceAway_2'], inplace=True)

df['NearbyPlaces'] = df['NearbyPlaces'].apply(
    lambda places: str(places) if isinstance(places, dict) else ''
)

# %%
df['NearbyPlaces'][0]
# Out:
# "{'L P Savani School': 'is 0.2 km away', 'BACHPAN Children hospital': 'is 0.4 km away'}"

# %%
places_df = df[['SocietyName', 'NearbyPlaces']]

# %%
import ast

def distance_to_meters(distance_str):
    try:
        if 'km' in distance_str:
            return float(distance_str.split()[1]) * 1000
        elif 'Meter' in distance_str or 'meter' in distance_str:
            return float(distance_str.split()[0])
        else:
            return None
    except:
        return None

location_matrix = {}
for index, row in places_df.iterrows():
    distances = {}
    for location, distance in ast.literal_eval(row['NearbyPlaces']).items():
        distances[location] = distance_to_meters(distance)
    location_matrix[index] = distances

# Convert the dictionary to a dataframe
location_df = pd.DataFrame.from_dict(location_matrix, orient='index')

# Display the first few rows
location_df.head()
# Out:
#     L P Savani School  BACHPAN Children hospital  Agarwal Vidya Vihar  \
# 0               200.0                      400.0                  NaN
# 8               500.0                      700.0                  NaN
# 9               700.0                        NaN                  NaN
# 25              100.0                      300.0                  NaN
# 29              500.0                      400.0                  NaN
#
#     Amritam Multispeciality Hospital  The Radiant International School  \
# 0                                NaN                               NaN
# 8                                NaN                               NaN
# 9                                NaN                               NaN
# 25                               NaN                               NaN
# 29                               NaN                               NaN
#
#     Ortho Plus Hospital  Bhagwan Mahavir International School  \
# 0                   NaN                                   NaN
# 8                   NaN                                   NaN
# 9                   NaN                                   NaN
# 25                  NaN                                   NaN
# 29                  NaN                                   NaN
#
#     Shraddha Clinic - Dr. Khushbu Patel Jani  \
# 0                                        NaN
# 8                                        NaN
# 9                                        NaN
# 25                                       NaN
# 29                                       NaN
#
#     Shishukunj Vidya Vihar & L B Contractor School  Vesu Prathmik school  ...  \
# 0                                              NaN                   NaN  ...
# 8                                              NaN                   NaN  ...
# 9                                              NaN                   NaN  ...
# 25                                             NaN                   NaN  ...
# 29                                             NaN                   NaN  ...
#
#     Nilkanth Aarogyadham Surat  Aashadeep Vidhyalay 1  \
# 0                          NaN                    NaN
# 8                          NaN                    NaN
# 9                          NaN                    NaN
# 25                         NaN                    NaN
# 29                         NaN                    NaN
#
#     Shiv Orthopaedic Hospital  Hetvi Eye Hospital  Ramkabir High School  \
# 0                         NaN                 NaN                   NaN
# 8                         NaN                 NaN                   NaN
# 9                         NaN                 NaN                   NaN
# 25                        NaN                 NaN                   NaN
# 29                        NaN                 NaN                   NaN
#
#     Manavta Hospital (Medicare speciality centre)  \
# 0                                             NaN
# 8                                             NaN
# 9                                             NaN
# 25                                            NaN
# 29                                            NaN
#
#     Don Bosco High School , Sagaon.  Mahavir Hospital  L. P. Savani Academy  \
# 0                               NaN               NaN                   NaN
# 8                               NaN               NaN                   NaN
# 9                               NaN               NaN                   NaN
# 25                              NaN               NaN                   NaN
# 29                              NaN               NaN                   NaN
#
#     Om Women's and Children Hospital
# 0                                NaN
# 8                                NaN
# 9                                NaN
# 25                               NaN
# 29                               NaN
#
# [5 rows x 127 columns]

# %%
location_df.index = df.SocietyName

# %%
location_df.head()
# Out:
#                               L P Savani School  BACHPAN Children hospital  \
# SocietyName
# Aston Homes                               200.0                      400.0
# Raghuvir Spectrum                         500.0                      700.0
# Ramaa Residency                           700.0                        NaN
# Swagat Clifton                            100.0                      300.0
# Shyam Enclave Building A B C              500.0                      400.0
#
#                               Agarwal Vidya Vihar  \
# SocietyName
# Aston Homes                                   NaN
# Raghuvir Spectrum                             NaN
# Ramaa Residency                               NaN
# Swagat Clifton                                NaN
# Shyam Enclave Building A B C                  NaN
#
#                               Amritam Multispeciality Hospital  \
# SocietyName
# Aston Homes                                                NaN
# Raghuvir Spectrum                                          NaN
# Ramaa Residency                                            NaN
# Swagat Clifton                                             NaN
# Shyam Enclave Building A B C                               NaN
#
#                               The Radiant International School  \
# SocietyName
# Aston Homes                                                NaN
# Raghuvir Spectrum                                          NaN
# Ramaa Residency                                            NaN
# Swagat Clifton                                             NaN
# Shyam Enclave Building A B C                               NaN
#
#                               Ortho Plus Hospital  \
# SocietyName
# Aston Homes                                   NaN
# Raghuvir Spectrum                             NaN
# Ramaa Residency                               NaN
# Swagat Clifton                                NaN
# Shyam Enclave Building A B C                  NaN
#
#                               Bhagwan Mahavir International School  \
# SocietyName
# Aston Homes                                                    NaN
# Raghuvir Spectrum                                              NaN
# Ramaa Residency                                                NaN
# Swagat Clifton                                                 NaN
# Shyam Enclave Building A B C                                   NaN
#
#                               Shraddha Clinic - Dr. Khushbu Patel Jani  \
# SocietyName
# Aston Homes                                                        NaN
# Raghuvir Spectrum                                                  NaN
# Ramaa Residency                                                    NaN
# Swagat Clifton                                                     NaN
# Shyam Enclave Building A B C                                       NaN
#
#                               Shishukunj Vidya Vihar & L B Contractor School  \
# SocietyName
# Aston Homes                                                              NaN
# Raghuvir Spectrum                                                        NaN
# Ramaa Residency                                                          NaN
# Swagat Clifton                                                           NaN
# Shyam Enclave Building A B C                                             NaN
#
#                               Vesu Prathmik school  ...  \
# SocietyName                                         ...
# Aston Homes                                    NaN  ...
# Raghuvir Spectrum                              NaN  ...
# Ramaa Residency                                NaN  ...
# Swagat Clifton                                 NaN  ...
# Shyam Enclave Building A B C                   NaN  ...
#
#                               Nilkanth Aarogyadham Surat  \
# SocietyName
# Aston Homes                                          NaN
# Raghuvir Spectrum                                    NaN
# Ramaa Residency                                      NaN
# Swagat Clifton                                       NaN
# Shyam Enclave Building A B C                         NaN
#
#                               Aashadeep Vidhyalay 1  \
# SocietyName
# Aston Homes                                     NaN
# Raghuvir Spectrum                               NaN
# Ramaa Residency                                 NaN
# Swagat Clifton                                  NaN
# Shyam Enclave Building A B C                    NaN
#
#                               Shiv Orthopaedic Hospital  Hetvi Eye Hospital  \
# SocietyName
# Aston Homes                                         NaN                 NaN
# Raghuvir Spectrum                                   NaN                 NaN
# Ramaa Residency                                     NaN                 NaN
# Swagat Clifton                                      NaN                 NaN
# Shyam Enclave Building A B C                        NaN                 NaN
#
#                               Ramkabir High School  \
# SocietyName
# Aston Homes                                    NaN
# Raghuvir Spectrum                              NaN
# Ramaa Residency                                NaN
# Swagat Clifton                                 NaN
# Shyam Enclave Building A B C                   NaN
#
#                               Manavta Hospital (Medicare speciality centre)  \
# SocietyName
# Aston Homes                                                             NaN
# Raghuvir Spectrum                                                       NaN
# Ramaa Residency                                                         NaN
# Swagat Clifton                                                          NaN
# Shyam Enclave Building A B C                                            NaN
#
#                               Don Bosco High School , Sagaon.  \
# SocietyName
# Aston Homes                                               NaN
# Raghuvir Spectrum                                         NaN
# Ramaa Residency                                           NaN
# Swagat Clifton                                            NaN
# Shyam Enclave Building A B C                              NaN
#
#                               Mahavir Hospital  L. P. Savani Academy  \
# SocietyName
# Aston Homes                                NaN                   NaN
# Raghuvir Spectrum                          NaN                   NaN
# Ramaa Residency                            NaN                   NaN
# Swagat Clifton                             NaN                   NaN
# Shyam Enclave Building A B C               NaN                   NaN
#
#                               Om Women's and Children Hospital
# SocietyName
# Aston Homes                                                NaN
# Raghuvir Spectrum                                          NaN
# Ramaa Residency                                            NaN
# Swagat Clifton                                             NaN
# Shyam Enclave Building A B C                               NaN
#
# [5 rows x 127 columns]

# %%
location_df.fillna(6900, inplace=True)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# Apply the scaler to the entire dataframe
location_df_normalized = pd.DataFrame(scaler.fit_transform(location_df), columns=location_df.columns, index=location_df.index)

# %%
location_df_normalized
# Out:
#                                       L P Savani School  \
# SocietyName
# Aston Homes                                   -4.103137
# Raghuvir Spectrum                             -3.908319
# Ramaa Residency                               -3.778441
# Swagat Clifton                                -4.168076
# Shyam Enclave Building A B C                  -3.908319
# ...                                                 ...
# Shaileshbhai Gonawala Sai Kg Heights           0.247795
# Flora Avenue                                   0.247795
# M D Om Palace                                  0.247795
# Green Park Complex                             0.247795
# Shyam Shree Niketan                            0.247795
#
#                                       BACHPAN Children hospital  \
# SocietyName
# Aston Homes                                           -3.636068
# Raghuvir Spectrum                                     -3.455279
# Ramaa Residency                                        0.281015
# Swagat Clifton                                        -3.696331
# Shyam Enclave Building A B C                          -3.636068
# ...                                                         ...
# Shaileshbhai Gonawala Sai Kg Heights                   0.281015
# Flora Avenue                                           0.281015
# M D Om Palace                                          0.281015
# Green Park Complex                                     0.281015
# Shyam Shree Niketan                                    0.281015
#
#                                       Agarwal Vidya Vihar  \
# SocietyName
# Aston Homes                                      0.247132
# Raghuvir Spectrum                                0.247132
# Ramaa Residency                                  0.247132
# Swagat Clifton                                   0.247132
# Shyam Enclave Building A B C                     0.247132
# ...                                                   ...
# Shaileshbhai Gonawala Sai Kg Heights             0.247132
# Flora Avenue                                     0.247132
# M D Om Palace                                    0.247132
# Green Park Complex                               0.247132
# Shyam Shree Niketan                              0.247132
#
#                                       Amritam Multispeciality Hospital  \
# SocietyName
# Aston Homes                                                   0.195379
# Raghuvir Spectrum                                             0.195379
# Ramaa Residency                                               0.195379
# Swagat Clifton                                                0.195379
# Shyam Enclave Building A B C                                  0.195379
# ...                                                                ...
# Shaileshbhai Gonawala Sai Kg Heights                          0.195379
# Flora Avenue                                                  0.195379
# M D Om Palace                                                 0.195379
# Green Park Complex                                            0.195379
# Shyam Shree Niketan                                           0.195379
#
#                                       The Radiant International School  \
# SocietyName
# ...                                                ...                   ...
# Shaileshbhai Gonawala Sai Kg Heights          0.072739              0.072739
# Flora Avenue                                  0.072739              0.072739
# M D Om Palace                                 0.072739              0.072739
# Green Park Complex                          -13.747727              0.072739
# Shyam Shree Niketan                           0.072739            -13.747727
#
#                                       Om Women's and Children Hospital
# SocietyName
# Aston Homes                                                   0.072739
# Raghuvir Spectrum                                             0.072739
# Ramaa Residency                                               0.072739
# Swagat Clifton                                                0.072739
# Shyam Enclave Building A B C                                  0.072739
# ...                                                                ...
# Shaileshbhai Gonawala Sai Kg Heights                          0.072739
# Flora Avenue                                                  0.072739
# M D Om Palace                                                 0.072739
# Green Park Complex                                            0.072739
# Shyam Shree Niketan                                         -13.747727
#
# [190 rows x 127 columns]

# %%
cosine_sim1 = cosine_similarity(location_df_normalized)

# %%
cosine_sim1.shape
# Out:
# (190, 190)

# %%
def recommend_properties_with_scores(property_name, top_n=247):
    
    cosine_sim_matrix = cosine_sim1
    
    # Get the similarity scores for the property using its name as the index
    sim_scores = list(enumerate(cosine_sim_matrix[location_df_normalized.index.get_loc(property_name)]))
    
    # Sort properties based on the similarity scores
    sorted_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # Get the indices and scores of the top_n most similar properties
    top_indices = [i[0] for i in sorted_scores[1:top_n+1]]
    top_scores = [i[1] for i in sorted_scores[1:top_n+1]]
    
    # Retrieve the names of the top properties using the indices
    top_properties = location_df_normalized.index[top_indices].tolist()
    
    # Create a dataframe with the results
    recommendations_df = pd.DataFrame({
        'PropertyName': top_properties,
        'SimilarityScore': top_scores
    })
    
    return recommendations_df

# Test the recommender function using a property name
recommend_properties_with_scores('Aston Homes')
# Out:
#                                  PropertyName  SimilarityScore
# 0                              Swagat Clifton         0.999993
# 1                          Avadh Copper Stone         0.999993
# 2              Happy Home Nakshatra Solitaire         0.999993
# 3                           Raghuvir Spectrum         0.999926
# 4                        Kush Crystal Heights         0.999878
# ..                                        ...              ...
# 184                        Milestone 7 Heaven        -0.090523
# 185                           Vaishnodevi Sky        -0.090653
# 186  Samarth Developers Surat Samarth Enclave        -0.091012
# 187                    Shree Kalyan Residency        -0.091102
# 188                           Ashirwad Avenue        -0.091102
#
# [189 rows x 2 columns]

# %% [markdown]
# # Recommendation using Description

# %%
desc_df = df[['SocietyName', 'Description']]

desc_df = desc_df.set_index('SocietyName')

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet, stopwords

nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
def remove_stopwords(text):
    new_text = []
    for word in text.split():
        if word in stopwords.words('english'):
            new_text.append('')
        else:
            new_text.append(word)
    x = new_text[:]
    new_text.clear()
    return " ".join(x)

desc_df['Description'] = desc_df['Description'].apply(remove_stopwords)

# %%
lemmatizer = WordNetLemmatizer()

desc_df['Description'] = desc_df['Description'].apply(lambda x:lemmatizer.lemmatize(x, pos='v'))

# %%
tfidf_vectorizer = TfidfVectorizer(stop_words='english', ngram_range=(1, 2))

tfidf_matrix = tfidf_vectorizer.fit_transform(desc_df['Description'])

# %%
tfidf_matrix.shape
# Out:
# (190, 1727)

# %%
cosine_sim2 = cosine_similarity(tfidf_matrix)

# %%
cosine_sim2.shape
# Out:
# (190, 190)

# %%
def recommend_properties_with_scores(property_name, top_n=190):
    
    cosine_sim_matrix = cosine_sim2
    
    # Get the similarity scores for the property using its name as the index
    sim_scores = list(enumerate(cosine_sim_matrix[desc_df.index.get_loc(property_name)]))
    
    # Sort properties based on the similarity scores
    sorted_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # Get the indices and scores of the top_n most similar properties
    top_indices = [i[0] for i in sorted_scores[1:top_n+1]]
    top_scores = [i[1] for i in sorted_scores[1:top_n+1]]
    
    # Retrieve the names of the top properties using the indices
    top_properties = desc_df.index[top_indices].tolist()
    
    # Create a dataframe with the results
    recommendations_df = pd.DataFrame({
        'PropertyName': top_properties,
        'SimilarityScore': top_scores
    })
    
    return recommendations_df

# Test the recommender function using a property name
recommend_properties_with_scores('Aston Homes')
# Out:
#                    PropertyName  SimilarityScore
# 0                 Western Villa         0.936161
# 1                   Vastu Shilp         0.936161
# 2                 Meera Heights         0.906823
# 3                 Aakash Earrth         0.780104
# 4                Aagam Prestige         0.636216
# ..                          ...              ...
# 184      Sangini Swapna Sangini         0.005470
# 185                SNS Splendid         0.005365
# 186            Mangalam Heights         0.004678
# 187  Rajhans Platinum Residency         0.002132
# 188     Happy Nakshatra Galaxia         0.001907
#
# [189 rows x 2 columns]

# %%
import pickle

with open('sim1.pkl', 'wb') as file:
    pickle.dump(cosine_sim1, file)

with open('sim2.pkl', 'wb') as file:
    pickle.dump(cosine_sim2, file)

with open('location_df.pkl', 'wb') as file:
    pickle.dump(location_df, file)
