# %%
import re

import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv('apartment.csv')

df.shape
# Out:
# (1415, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1415 entries, 0 to 1414
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SocietyName     971 non-null    object
#  1   BHK             1415 non-null   object
#  2   Furnishing      1415 non-null   object
#  3   BuiltUpArea     1415 non-null   object
#  4   Locality        1415 non-null   object
#  5   NearbyPlace_1   1413 non-null   object
#  6   DistanceAway_1  1413 non-null   object
#  7   NearbyPlace_2   1413 non-null   object
#  8   DistanceAway_2  1413 non-null   object
#  9   Description     1415 non-null   object
#  10  Highlights      593 non-null    object
# dtypes: object(11)
# memory usage: 121.7+ KB

# %%
df.duplicated().sum()
# Out:
# 23

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (1392, 11)

# %%
df.isna().sum()
# Out:
# SocietyName       440
# BHK                 0
# Furnishing          0
# BuiltUpArea         0
# Locality            0
# NearbyPlace_1       2
# DistanceAway_1      2
# NearbyPlace_2       2
# DistanceAway_2      2
# Description         0
# Highlights        817
# dtype: int64

# %%
df = df[~(df['SocietyName'].isna())]

df.reset_index(drop=True, inplace=True)

# %%
df.shape
# Out:
# (952, 11)

# %%
df.drop_duplicates(subset=['SocietyName'], inplace=True)

# %%
df.shape

df.reset_index(drop=True, inplace=True)

# %%
df.isna().sum()
# Out:
# SocietyName         0
# BHK                 0
# Furnishing          0
# BuiltUpArea         0
# Locality            0
# NearbyPlace_1       1
# DistanceAway_1      1
# NearbyPlace_2       1
# DistanceAway_2      1
# Description         0
# Highlights        207
# dtype: int64

# %%
df.shape
# Out:
# (391, 11)

# %%
df.sample(10)
# Out:
#                   SocietyName  \
# 37                 Anand Ilyf
# 19       Shatrunjay Apartment
# 311          Safal Parisar II
# 103             Orchid Heaven
# 17          Shripad Residency
# 254             Safal Seventy
# 158          Sun Rising Homes
# 148  Devkinandan Parmeshwar 4
# 213            Sheladia Sarva
# 183           Malabar Exotica
#
#                                                    BHK       Furnishing  \
# 37   3 BHK Flat for rent in Vaishno Devi Circle, Ah...  Fully Furnished
# 19      3 BHK Flat for rent in Ramdev Nagar, Ahmedabad  Fully Furnished
# 311      3 BHK Flat for rent in South Bopal, Ahmedabad  Fully Furnished
# 103            3 BHK Flat for rent in Shela, Ahmedabad   Semi Furnished
# 17              3 BHK Flat for rent in Gota, Ahmedabad  Fully Furnished
# 254  4 BHK Flat for rent in Iscon Ambli Road, Ahmed...  Fully Furnished
# 158             2 BHK Flat for rent in Gota, Ahmedabad   Semi Furnished
# 148       2 BHK Flat for rent in Chandkheda, Ahmedabad  Fully Furnished
# 213            3 BHK Flat for rent in Shela, Ahmedabad   Semi Furnished
# 183           3 BHK Flat for rent in Tragad, Ahmedabad      Unfurnished
#
#     BuiltUpArea                                           Locality  \
# 37   1800 sq.ft  3 BHK Flat for rent in Vaishno Devi Circle, Ah...
# 19   1700 sq.ft     3 BHK Flat for rent in Ramdev Nagar, Ahmedabad
# 311  1905 sq.ft      3 BHK Flat for rent in South Bopal, Ahmedabad
# 103  1985 sq.ft            3 BHK Flat for rent in Shela, Ahmedabad
# 17   1800 sq.ft             3 BHK Flat for rent in Gota, Ahmedabad
# 254  5400 sq.ft  4 BHK Flat for rent in Iscon Ambli Road, Ahmed...
# 158   800 sq.ft             2 BHK Flat for rent in Gota, Ahmedabad
# 148  1200 sq.ft       2 BHK Flat for rent in Chandkheda, Ahmedabad
# 213  1500 sq.ft            3 BHK Flat for rent in Shela, Ahmedabad
# 183  1875 sq.ft           3 BHK Flat for rent in Tragad, Ahmedabad
#
#                                          NearbyPlace_1  DistanceAway_1  \
# 37                                     H3 World School  is 1.6 km away
# 19                      Anand Niketan Group of Schools  is 0.5 km away
# 311  eduMETA THE i-SCHOOL South Bopal Ahmedabad Guj...  is 0.1 km away
# 103                      Lakshaya International School  is 3.3 km away
# 17                  SMT K N Patel International School    is 1 km away
# 254                     Anand Niketan Group of Schools  is 0.1 km away
# 158                 SMT K N Patel International School  is 1.7 km away
# 148  Global Indian International School In Ahmedaba...  is 0.9 km away
# 213      LDR International School - South Bopal Branch  is 1.6 km away
# 183                                    H3 World School  is 0.5 km away
#
#                                          NearbyPlace_2  DistanceAway_2  \
# 37   Ashirvad Hospital - Best Gynecologist | Orthop...  is 3.3 km away
# 19                    Shalby Multi-Specialty Hospitals  is 0.9 km away
# 311  Sannidhya Multi Speciality Hospital-Gynecologi...  is 0.2 km away
# 103               Suryam Children Hospital South Bopal  is 2.7 km away
# 17   Mansi Women's Hospital - Best Gynec Hospital -...    is 1 km away
# 254                                      Epic Hospital  is 1.9 km away
# 158  Mansi Women's Hospital - Best Gynec Hospital -...  is 1.1 km away
# 148  Jenshiv Hospital - Physician - Diabetologist i...  is 2.1 km away
# 213                        Aalpa's children's hospital  is 2.1 km away
# 183  Ashirvad Hospital - Best Gynecologist | Orthop...  is 4.2 km away
#
#                                            Description  \
# 37   Anand eyelife it's good apartment it's fully f...
# 19   Your search for a spacious home at affordable ...
# 311  This property is good and good locality 3bhk f...
# 103  A residential flat available for rent in the p...
# 17   Sripad residency it's good apartment in gota n...
# 254  This Apartment can be a comfortable and afford...
# 158  Are you looking for an affordable Apartment fo...
# 148  Check out this Apartment available for rent in...
# 213  This Apartment can be a comfortable and afford...
# 183  3.5bhk flat on rent in malabar exotica, new fl...
#
#                                             Highlights
# 37   Property HighlightsAerobics RoomAmphitheatre24...
# 19   Property HighlightsChildren Play AreaIndoor Ga...
# 311                                                NaN
# 103  Property Highlights24 Hours Concierge24x7 Secu...
# 17   Property HighlightsATMAnti Skid TitlesAmphithe...
# 254                                                NaN
# 158  Property Highlights24x7 SecurityATMChildren Pl...
# 148  Property Highlights24x7 SecurityATMChildren Pl...
# 213                                                NaN
# 183                                                NaN

# %%
df.drop(columns=['Highlights','Locality'], inplace=True)

# %%
df.isna().sum()
# Out:
# SocietyName       0
# BHK               0
# Furnishing        0
# BuiltUpArea       0
# NearbyPlace_1     1
# DistanceAway_1    1
# NearbyPlace_2     1
# DistanceAway_2    1
# Description       0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.sample(1)
# Out:
#          SocietyName                                             BHK  \
# 94  Sparsh Residency  3 BHK Flat for rent in Science City, Ahmedabad
#
#         Furnishing BuiltUpArea      NearbyPlace_1  DistanceAway_1  \
# 94  Semi Furnished  1800 sq.ft  S S Divine School  is 2.5 km away
#
#                                         NearbyPlace_2  DistanceAway_2  \
# 94  Vasundhara Children Hospital . Breastfeeding C...  is 3.3 km away
#
#                                           Description
# 94  Here is an excellent 3 BHK Apartment available...

# %% [markdown]
# # Recommendation using Nearby Location

# %%
df['Bhk'] = df['BHK'].str.split(" ").str.get(0)
df['Description'] = df['Description'].str.split('.').apply(lambda x: '.'.join(x[:-4]) if len(x) > 4 else '')

df.drop('BHK', axis=1, inplace=True)

# %%
df.head(1)
# Out:
#               SocietyName       Furnishing BuiltUpArea  \
# 0  Ganesh Malabar Retreat  Fully Furnished  1200 sq.ft
#
#                  NearbyPlace_1  DistanceAway_1           NearbyPlace_2  \
# 0  Nirma Vidyavihar - Chharodi  is 0.5 km away  SGVP Holistic Hospital
#
#    DistanceAway_2                                        Description Bhk
# 0  is 2.2 km away  Malabar retreat it's totally new apartment nea...   2

# %%
df['NearbyPlaces'] = df.apply(lambda row: {
    row['NearbyPlace_1']: row['DistanceAway_1'],
    row['NearbyPlace_2']: row['DistanceAway_2']
}, axis=1)

df.drop(columns=['NearbyPlace_1', 'DistanceAway_1', 'NearbyPlace_2', 'DistanceAway_2'], inplace=True)

df['NearbyPlaces'] = df['NearbyPlaces'].apply(
    lambda places: str(places) if isinstance(places, dict) else ''
)

# %%
df['NearbyPlaces'][0]
# Out:
# "{'Nirma Vidyavihar - Chharodi': 'is 0.5 km away', 'SGVP Holistic Hospital': 'is 2.2 km away'}"

# %%
places_df = df[['SocietyName', 'NearbyPlaces']]

# %%
import ast

def distance_to_meters(distance_str):
    try:
        if 'km' in distance_str:
            return float(distance_str.split()[1]) * 1000
        elif 'Meter' in distance_str or 'meter' in distance_str:
            return float(distance_str.split()[0])
        else:
            return None
    except:
        return None

location_matrix = {}
for index, row in places_df.iterrows():
    distances = {}
    for location, distance in ast.literal_eval(row['NearbyPlaces']).items():
        distances[location] = distance_to_meters(distance)
    location_matrix[index] = distances

# Convert the dictionary to a dataframe
location_df = pd.DataFrame.from_dict(location_matrix, orient='index')

# Display the first few rows
location_df.head()
# Out:
#      Nirma Vidyavihar - Chharodi  SGVP Holistic Hospital  \
# 0                          500.0                  2200.0
# 11                        1600.0                     NaN
# 70                         400.0                     NaN
# 80                         600.0                     NaN
# 102                        400.0                     NaN
#
#      Puna International School  \
# 0                          NaN
# 11                         NaN
# 70                         NaN
# 80                         NaN
# 102                        NaN
#
#      Ashirvad Hospital - Best Gynecologist | Orthopaedic | Psychiatrist | Neurologist | Pediatrician Doctor Hospital  \
# 0                                                  NaN
# 11                                              1900.0
# 70                                                 NaN
# 80                                                 NaN
# 102                                                NaN
#
#      Taksh Education  Balaji Horizon Women's Hospital  \
# 0                NaN                              NaN
# 11               NaN                              NaN
# 70               NaN                              NaN
# 80               NaN                              NaN
# 102              NaN                              NaN
#
#      Lakshaya International School  Suryam Children Hospital South Bopal  \
# 0                              NaN                                   NaN
# 11                             NaN                                   NaN
# 70                             NaN                                   NaN
# 80                             NaN                                   NaN
# 102                            NaN                                   NaN
#
#      BHIMANI Children's Hospital & Vaccination Centre  \
# 0                                                 NaN
# 11                                                NaN
# 70                                                NaN
# 80                                                NaN
# 102                                               NaN
#
#      Sumati Vidhya Vihar, Ghatlodiya,  ...  Sai Women's Care Hospital  \
# 0                                 NaN  ...                        NaN
# 11                                NaN  ...                        NaN
# 70                                NaN  ...                        NaN
# 80                                NaN  ...                        NaN
# 102                               NaN  ...                        NaN
#
#      Adani Vidya Mandir  \
# 0                   NaN
# 11                  NaN
# 70                  NaN
# 80                  NaN
# 102                 NaN
#
#      ZAHRA MEDIPLUS HOSPITAL (Multispecialty) - || Best Hospital, ICU And Emergency, Multispeciality Hospital  \
# 0                                                  NaN
# 11                                                 NaN
# 70                                                 NaN
# 80                                                 NaN
# 102                                                NaN
#
#      Gurukrupa Children Hospital  The Lighthouse Montessori School  \
# 0                            NaN                               NaN
# 11                           NaN                               NaN
# 70                           NaN                               NaN
# 80                           NaN                               NaN
# 102                          NaN                               NaN
#
#      Zebar School for Children  Global Longlife Hospital & Research Limited  \
# 0                          NaN                                          NaN
# 11                         NaN                                          NaN
# 70                         NaN                                          NaN
# 80                         NaN                                          NaN
# 102                        NaN                                          NaN
#
#      Doon School of Excellence, New Maninagar  \
# 0                                         NaN
# 11                                        NaN
# 70                                        NaN
# 80                                        NaN
# 102                                       NaN
#
#      Jivan Gastro And Gynec Hospital | Liver Hospital | Maternity Hospital | Gastroenterologist | Pregnancy Care in vastral  \
# 0                                                  NaN
# 11                                                 NaN
# 70                                                 NaN
# 80                                                 NaN
# 102                                                NaN
#
#      Shree Sahajanand Gurukul - Koteshwar
# 0                                     NaN
# 11                                    NaN
# 70                                    NaN
# 80                                    NaN
# 102                                   NaN
#
# [5 rows x 171 columns]

# %%
location_df.index = df.SocietyName

# %%
location_df.head()
# Out:
#                               Nirma Vidyavihar - Chharodi  \
# SocietyName
# Ganesh Malabar Retreat                              500.0
# Vivaan Eminence                                    1600.0
# Om Sky                                              400.0
# Orchid Legacy                                       600.0
# Shiv Sadhna Skywalk Manglaam                        400.0
#
#                               SGVP Holistic Hospital  \
# SocietyName
# Ganesh Malabar Retreat                        2200.0
# Vivaan Eminence                                  NaN
# Om Sky                                           NaN
# Orchid Legacy                                    NaN
# Shiv Sadhna Skywalk Manglaam                     NaN
#
#                               Puna International School  \
# SocietyName
# Ganesh Malabar Retreat                              NaN
# Vivaan Eminence                                     NaN
# Om Sky                                              NaN
# Orchid Legacy                                       NaN
# Shiv Sadhna Skywalk Manglaam                        NaN
#
#                               Ashirvad Hospital - Best Gynecologist | Orthopaedic | Psychiatrist | Neurologist | Pediatrician Doctor Hospital  \
# SocietyName
# Ganesh Malabar Retreat                                                      NaN
# Vivaan Eminence                                                          1900.0
# Om Sky                                                                      NaN
# Orchid Legacy                                                               NaN
# Shiv Sadhna Skywalk Manglaam                                                NaN
#
#                               Taksh Education  \
# SocietyName
# Ganesh Malabar Retreat                    NaN
# Vivaan Eminence                           NaN
# Om Sky                                    NaN
# Orchid Legacy                             NaN
# Shiv Sadhna Skywalk Manglaam              NaN
#
#                               Balaji Horizon Women's Hospital  \
# SocietyName
# Ganesh Malabar Retreat                                    NaN
# Vivaan Eminence                                           NaN
# Om Sky                                                    NaN
# Orchid Legacy                                             NaN
# Shiv Sadhna Skywalk Manglaam                              NaN
#
#                               Lakshaya International School  \
# SocietyName
# Ganesh Malabar Retreat                                  NaN
# Vivaan Eminence                                         NaN
# Om Sky                                                  NaN
# Orchid Legacy                                           NaN
# Shiv Sadhna Skywalk Manglaam                            NaN
#
#                               Suryam Children Hospital South Bopal  \
# SocietyName
# Ganesh Malabar Retreat                                         NaN
# Vivaan Eminence                                                NaN
# Om Sky                                                         NaN
# Orchid Legacy                                                  NaN
# Shiv Sadhna Skywalk Manglaam                                   NaN
#
#                               BHIMANI Children's Hospital & Vaccination Centre  \
# SocietyName
# Ganesh Malabar Retreat                                                     NaN
# Vivaan Eminence                                                            NaN
# Om Sky                                                                     NaN
# Orchid Legacy                                                              NaN
# Shiv Sadhna Skywalk Manglaam                                               NaN
#
#                               Sumati Vidhya Vihar, Ghatlodiya,  ...  \
# SocietyName                                                     ...
# Ganesh Malabar Retreat                                     NaN  ...
# Vivaan Eminence                                            NaN  ...
# Om Sky                                                     NaN  ...
# Orchid Legacy                                              NaN  ...
# Shiv Sadhna Skywalk Manglaam                               NaN  ...
#
#                               Sai Women's Care Hospital  Adani Vidya Mandir  \
# SocietyName
# Ganesh Malabar Retreat                              NaN                 NaN
# Vivaan Eminence                                     NaN                 NaN
# Om Sky                                              NaN                 NaN
# Orchid Legacy                                       NaN                 NaN
# Shiv Sadhna Skywalk Manglaam                        NaN                 NaN
#
#                               ZAHRA MEDIPLUS HOSPITAL (Multispecialty) - || Best Hospital, ICU And Emergency, Multispeciality Hospital  \
# SocietyName
# Ganesh Malabar Retreat                                                      NaN
# Vivaan Eminence                                                             NaN
# Om Sky                                                                      NaN
# Orchid Legacy                                                               NaN
# Shiv Sadhna Skywalk Manglaam                                                NaN
#
#                               Gurukrupa Children Hospital  \
# SocietyName
# Ganesh Malabar Retreat                                NaN
# Vivaan Eminence                                       NaN
# Om Sky                                                NaN
# Orchid Legacy                                         NaN
# Shiv Sadhna Skywalk Manglaam                          NaN
#
#                               The Lighthouse Montessori School  \
# SocietyName
# Ganesh Malabar Retreat                                     NaN
# Vivaan Eminence                                            NaN
# Om Sky                                                     NaN
# Orchid Legacy                                              NaN
# Shiv Sadhna Skywalk Manglaam                               NaN
#
#                               Zebar School for Children  \
# SocietyName
# Ganesh Malabar Retreat                              NaN
# Vivaan Eminence                                     NaN
# Om Sky                                              NaN
# Orchid Legacy                                       NaN
# Shiv Sadhna Skywalk Manglaam                        NaN
#
#                               Global Longlife Hospital & Research Limited  \
# SocietyName
# Ganesh Malabar Retreat                                                NaN
# Vivaan Eminence                                                       NaN
# Om Sky                                                                NaN
# Orchid Legacy                                                         NaN
# Shiv Sadhna Skywalk Manglaam                                          NaN
#
#                               Doon School of Excellence, New Maninagar  \
# SocietyName
# Ganesh Malabar Retreat                                             NaN
# Vivaan Eminence                                                    NaN
# Om Sky                                                             NaN
# Orchid Legacy                                                      NaN
# Shiv Sadhna Skywalk Manglaam                                       NaN
#
#                               Jivan Gastro And Gynec Hospital | Liver Hospital | Maternity Hospital | Gastroenterologist | Pregnancy Care in vastral  \
# SocietyName
# Ganesh Malabar Retreat                                                      NaN
# Vivaan Eminence                                                             NaN
# Om Sky                                                                      NaN
# Orchid Legacy                                                               NaN
# Shiv Sadhna Skywalk Manglaam                                                NaN
#
#                               Shree Sahajanand Gurukul - Koteshwar
# SocietyName
# Ganesh Malabar Retreat                                         NaN
# Vivaan Eminence                                                NaN
# Om Sky                                                         NaN
# Orchid Legacy                                                  NaN
# Shiv Sadhna Skywalk Manglaam                                   NaN
#
# [5 rows x 171 columns]

# %%
location_df.fillna(6900, inplace=True)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# Apply the scaler to the entire dataframe
location_df_normalized = pd.DataFrame(scaler.fit_transform(location_df), columns=location_df.columns, index=location_df.index)

# %%
location_df_normalized
# Out:
#                               Nirma Vidyavihar - Chharodi  \
# SocietyName
# Ganesh Malabar Retreat                          -8.287658
# Vivaan Eminence                                 -6.841784
# Om Sky                                          -8.419101
# Orchid Legacy                                   -8.156215
# Shiv Sadhna Skywalk Manglaam                    -8.419101
# ...                                                   ...
# Savvy Solaris                                    0.124702
# Padmanabh Dwarkesh Antilia                       0.124702
# Gala Luxuria                                     0.124702
# Gala Swing                                       0.124702
# Amaya 78 at Gokuldham                            0.124702
#
#                               SGVP Holistic Hospital  \
# SocietyName
# Ganesh Malabar Retreat                    -11.039952
# Vivaan Eminence                             0.088028
# Om Sky                                      0.088028
# Orchid Legacy                               0.088028
# Shiv Sadhna Skywalk Manglaam                0.088028
# ...                                              ...
# Savvy Solaris                               0.088028
# Padmanabh Dwarkesh Antilia                  0.088028
# Gala Luxuria                                0.088028
# Gala Swing                                  0.088028
# Amaya 78 at Gokuldham                       0.088028
#
#                               Puna International School  \
# SocietyName
# Ganesh Malabar Retreat                         0.206435
# Vivaan Eminence                                0.206435
# Om Sky                                         0.206435
# Orchid Legacy                                  0.206435
# Shiv Sadhna Skywalk Manglaam                   0.206435
# ...                                                 ...
# Savvy Solaris                                  0.206435
# Padmanabh Dwarkesh Antilia                     0.206435
# Gala Luxuria                                   0.206435
# Gala Swing                                     0.206435
# Amaya 78 at Gokuldham                          0.206435
#
#                               Ashirvad Hospital - Best Gynecologist | Orthopaedic | Psychiatrist | Neurologist | Pediatrician Doctor Hospital  \
# SocietyName
# Ganesh Malabar Retreat                                                 0.269946
# Vivaan Eminence                                                       -3.552815
# Om Sky                                                                 0.269946
# Orchid Legacy                                                          0.269946
# Shiv Sadhna Skywalk Manglaam                                           0.269946
# ...                                                                         ...
# Savvy Solaris                                                          0.269946
# Padmanabh Dwarkesh Antilia                                             0.269946
# Gala Luxuria                                                           0.269946
# Gala Swing                                                             0.269946
# Amaya 78 at Gokuldham                                                  0.269946
#
#                               Taksh Education  \
# SocietyName
# Ganesh Malabar Retreat               0.050702
# Vivaan Eminence                      0.050702
# Om Sky                               0.050702
# Orchid Legacy                        0.050702
# Shiv Sadhna Skywalk Manglaam         0.050702
# ...                                       ...
# Savvy Solaris                        0.050702
# Padmanabh Dwarkesh Antilia           0.050702
# Gala Luxuria                         0.050702
# Gala Swing                           0.050702
# Amaya 78 at Gokuldham                0.050702
#
#                               Balaji Horizon Women's Hospital  \
# SocietyName
# Ganesh Malabar Retreat                               0.050702
# Vivaan Eminence                                      0.050702
# Om Sky                                               0.050702
# Orchid Legacy                                        0.050702
# Shiv Sadhna Skywalk Manglaam                         0.050702
# ...                                                       ...
# Savvy Solaris                                        0.050702
# Padmanabh Dwarkesh Antilia                                             0.050702
# Gala Luxuria                                                           0.050702
# Gala Swing                                                             0.050702
# Amaya 78 at Gokuldham                                                -19.723083
#
#                               Shree Sahajanand Gurukul - Koteshwar
# SocietyName
# Ganesh Malabar Retreat                                    0.050702
# Vivaan Eminence                                           0.050702
# Om Sky                                                    0.050702
# Orchid Legacy                                             0.050702
# Shiv Sadhna Skywalk Manglaam                              0.050702
# ...                                                            ...
# Savvy Solaris                                             0.050702
# Padmanabh Dwarkesh Antilia                                0.050702
# Gala Luxuria                                              0.050702
# Gala Swing                                                0.050702
# Amaya 78 at Gokuldham                                     0.050702
#
# [390 rows x 171 columns]

# %%
cosine_sim1 = cosine_similarity(location_df_normalized)

# %%
cosine_sim1.shape
# Out:
# (390, 390)

# %%
def recommend_properties_with_scores(property_name, top_n=247):
    
    cosine_sim_matrix = cosine_sim1
    
    # Get the similarity scores for the property using its name as the index
    sim_scores = list(enumerate(cosine_sim_matrix[location_df_normalized.index.get_loc(property_name)]))
    
    # Sort properties based on the similarity scores
    sorted_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # Get the indices and scores of the top_n most similar properties
    top_indices = [i[0] for i in sorted_scores[1:top_n+1]]
    top_scores = [i[1] for i in sorted_scores[1:top_n+1]]
    
    # Retrieve the names of the top properties using the indices
    top_properties = location_df_normalized.index[top_indices].tolist()
    
    # Create a dataframe with the results
    recommendations_df = pd.DataFrame({
        'PropertyName': top_properties,
        'SimilarityScore': top_scores
    })
    
    return recommendations_df

# Test the recommender function using a property name
recommend_properties_with_scores('Ganesh Malabar Retreat')
# Out:
#                     PropertyName  SimilarityScore
# 0                  Sun Shela One         0.698612
# 1                  Gala Celestia         0.698612
# 2                Aaryan Euphoria         0.544175
# 3                Vivaan Eminence         0.521487
# 4                         Om Sky         0.511558
# ..                           ...              ...
# 242                Savvy Studioz        -0.017995
# 243         Omkar Earth Paradise        -0.018001
# 244                    The Crest        -0.018093
# 245  Shivalik Sharda Park view 2        -0.018104
# 246              Takshashila Air        -0.018105
#
# [247 rows x 2 columns]

# %% [markdown]
# # Recommendation using Description

# %%
desc_df = df[['SocietyName', 'Description']]

desc_df = desc_df.set_index('SocietyName')

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet, stopwords

nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
def remove_stopwords(text):
    new_text = []
    for word in text.split():
        if word in stopwords.words('english'):
            new_text.append('')
        else:
            new_text.append(word)
    x = new_text[:]
    new_text.clear()
    return " ".join(x)

desc_df['Description'] = desc_df['Description'].apply(remove_stopwords)

# %%
lemmatizer = WordNetLemmatizer()

desc_df['Description'] = desc_df['Description'].apply(lambda x:lemmatizer.lemmatize(x, pos='v'))

# %%
tfidf_vectorizer = TfidfVectorizer(stop_words='english', ngram_range=(1, 2))

tfidf_matrix = tfidf_vectorizer.fit_transform(desc_df['Description'])

# %%
tfidf_matrix.shape
# Out:
# (390, 3307)

# %%
cosine_sim2 = cosine_similarity(tfidf_matrix)

# %%
cosine_sim2.shape
# Out:
# (390, 390)

# %%
def recommend_properties_with_scores(property_name, top_n=190):
    
    cosine_sim_matrix = cosine_sim2
    
    # Get the similarity scores for the property using its name as the index
    sim_scores = list(enumerate(cosine_sim_matrix[desc_df.index.get_loc(property_name)]))
    
    # Sort properties based on the similarity scores
    sorted_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # Get the indices and scores of the top_n most similar properties
    top_indices = [i[0] for i in sorted_scores[1:top_n+1]]
    top_scores = [i[1] for i in sorted_scores[1:top_n+1]]
    
    # Retrieve the names of the top properties using the indices
    top_properties = desc_df.index[top_indices].tolist()
    
    # Create a dataframe with the results
    recommendations_df = pd.DataFrame({
        'PropertyName': top_properties,
        'SimilarityScore': top_scores
    })
    
    return recommendations_df

# Test the recommender function using a property name
recommend_properties_with_scores('Ganesh Malabar Retreat')
# Out:
#                                     PropertyName  SimilarityScore
# 0                              Shripad Residency         0.661176
# 1                                  Alaya Heights         0.643242
# 2    Himalaya and Mainland Pinnacle Block A To D         0.553928
# 3                                     Gala Haven         0.541043
# 4                              Dwarkesh Opulence         0.524672
# ..                                           ...              ...
# 185                                   Flora Iris         0.044886
# 186                                      Samyaka         0.044315
# 187                                    The Crest         0.043673
# 188                             Aamrakunj Gracia         0.043673
# 189                       Satyamev Royal Parisar         0.043673
#
# [190 rows x 2 columns]

# %%
import pickle

with open('sim1.pkl', 'wb') as file:
    pickle.dump(cosine_sim1, file)

with open('sim2.pkl', 'wb') as file:
    pickle.dump(cosine_sim2, file)

with open('location_df.pkl', 'wb') as file:
    pickle.dump(location_df, file)
